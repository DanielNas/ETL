# %%
import pandas as pd
import os

# %%
caminho = r'C:\Users\Daniel\OneDrive\Ambiente de Trabalho\Projetos ETL\Olist brazil\ETL\data\raw'

# %%
listar_arquivos = os.listdir(caminho)
print(listar_arquivos)
# Out:
# ['olist_customers_dataset.csv', 'olist_geolocation_dataset.csv', 'olist_orders_dataset.csv', 'olist_order_items_dataset.csv', 'olist_order_payments_dataset.csv', 'olist_order_reviews_dataset.csv', 'olist_products_dataset.csv', 'olist_sellers_dataset.csv', 'product_category_name_translation.csv']

# %%
clientes = 'olist_customers_dataset.csv' 
geolocali = 'olist_geolocation_dataset.csv' 
pedidos = 'olist_orders_dataset.csv' 
itens = 'olist_order_items_dataset.csv'
pagamentos = 'olist_order_payments_dataset.csv'
reviews = 'olist_order_reviews_dataset.csv'
produtos = 'olist_products_dataset.csv'
fornecedores = 'olist_sellers_dataset.csv'
categoria_produtos = 'product_category_name_translation.csv'

# %%
caminho_clientes = os.path.join(caminho, clientes)
tab_clientes = pd.read_csv(caminho_clientes)
tab_clientes.head(10)
tab_clientes.info()

# %%
caminho_pedidos = os.path.join(caminho, pedidos)
tab_pedidos= pd.read_csv(caminho_pedidos)
tab_pedidos.head(10)
# tab_pedidos.info()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# 5  a4591c265e18cb1dcee52889e2d8acc3  503740e9ca751ccdda7ba28e9ab8f608
# 6  136cce7faa42fdb2cefd53fdc79a6098  ed0271e0b7da060a393796590e7b737a
# 7  6514b8ad8028c9f2cc2374ded245783f  9bdf08b4b3b52b5526ff42d37d47f222
# 8  76c6e866289321a7c93b82b54852dc33  f54a9f0e6b351c431402b8461ea51999
# 9  e69bfb5eb88e0ed6a785585b27e16dbf  31ad1d1b63eb9962463f764d4e6e0c9d
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# ...
